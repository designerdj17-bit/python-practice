# %% [markdown]
# <a href="https://colab.research.google.com/github/designerdj17-bit/python-practice/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("------------- BIO DATA ------------")
user_name= "Dheer Jain"
print("Name            : ",user_name)
father_name= "Akshay Jain"
print("Father Name     : ",father_name)
class1="VII"
print("Class           : ",class1)
number2= 9413752964
print("Number          : ",number2)
Friend_name= "Yuvraj"
print("Friend Name     : ",Friend_name)
Favourite_food= "Pasta and Pizza"
print("Favourite food  : ",Favourite_food)
Age_4= 13
print("Age             : ",Age_4)
Country_1= "India"
print("country         : ",Country_1)
State= "Rajisthan"
print("State           : ",State)
City= "Ajmer",
print("city            : ",City)
print("-------------------------------------")
# Out:
# ------------- BIO DATA ------------
# enter your nameraju
# Name            :  raju
# enter yourfather namehh
# Father Name     :  hh
# Class           :  VII
# Number          :  9413752964
# Friend Name     :  Yuvraj
# Favourite food  :  Pasta and Pizza
# Age             :  13
# country         :  India
# State           :  Rajisthan
# city            :  ('Ajmer',)
# -------------------------------------

# %%
item1="lays"
item2="milk"
item3="silk"
item4="phone"
item5="watch"
price_of_item1=60
price_of_item2=40
price_of_item3=100
price_of_item4=156000
price_of_item5=14300
print(" item1 : ", item1," price", price_of_item1)
print("name of item2 : ", item2," price of item2", price_of_item2)
print("name of item3 : ", item3," price of item3", price_of_item3)
print("name of item4 : ", item4," price of item4", price_of_item4)
print("name of item5 : ", item5," price of item5", price_of_item5)
total_bill=price_of_item1+price_of_item2+price_of_item3+price_of_item4+price_of_item5
print("total_bill      : ", total_bill)
# Out:
#  item1 :  lays  price 60
# name of item2 :  milk  price of item2 40
# name of item3 :  silk  price of item3 100
# name of item4 :  phone  price of item4 156000
# name of item5 :  watch  price of item5 14300
# total_bill      :  170500

# %%
item1="pizza"
item2="pasta"
price_of_item1=500
price_of_item2=300
print("name of item1 : ", item1,"   price of item1", price_of_item1)
print("name of item2 : ", item2,"   price of item2", price_of_item2)
total_bill=price_of_item1+price_of_item2
print("total bill      :", total_bill)
# Out:
# name of item1 :  pizza    price of item1 500
# name of item2 :  pasta    price of item2 300
# total bill      : 800

# %%
a=2
b=4
print(a+2)
# Out:
# 4

# %%
a="20909984"
b="4777"
print(a+2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1825/89949971.py in <cell line: 0>()
#       1 a="20909984"
#       2 b="4777"
# ----> 3 print(a+2)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print("----------BILL----------")
print("S.NO. Food Odered    Rate")
print("1.    Pizza       :  350")
print("2.    White Pasta :  150" )
print("3.    Burger      :  215")
print("4.    Maggie      :   50")
print()

print("        Total  :   765")
print()
print("Have a good day")
print()
print("---------------------------")
# Out:
# ----------BILL----------
# S.NO. Food Odered    Rate
# 1.    Pizza       :  350
# 2.    White Pasta :  150
# 3.    Burger      :  215
# 4.    Maggie      :   50
#
#         Total  :   765
#
# Have a good day
#
# ---------------------------

# %%
print("---------------BLINKIT---------------")
print(" ----------------BILL---------------")
print()
print("S.NO.    ORDER      QUANTITY    RATE")
print("1.       Lays          4         80 ")
print("2.       Dairy Milk    2         40 ")
print("3.       potato        1kg       90")
print("4.       Lady Finger  1.5kg     150")
print("5.       Milk          1kg       50")
print("6.       5 star        4         20")
print("7.       Choco Pie     2         20")
print()
print("                  Total  :  450")
print("                Have A Greatful Day")
print("-----------------------------------------")
# Out:
# ---------------BLINKIT---------------
#  ----------------BILL---------------
#
# S.NO.    ORDER      QUANTITY    RATE
# 1.       Lays          4         80
# 2.       Dairy Milk    2         40
# 3.       potato        1kg       90
# 4.       Lady Finger  1.5kg     150
# 5.       Milk          1kg       50
# 6.       5 star        4         20
# 7.       Choco Pie     2         20
#
#                   Total  :  450
#                 Have A Greatful Day
# -----------------------------------------

# %%
first_number=6.7
second_number=9
sum= first_number + second_number
print(f"sum of the two numbers {sum}")
number_after_divide=sum/2
print("avarage of two numbers ",number_after_divide)
print("number multiplied by the divided number", number_after_divide * 5)
# Out:
# sum of the two numbers 15.7
# avarage of two numbers  7.85
# number multiplied by the divided number 39.25

# %%
name="dheerijijiji"
print(name)
# Out:
# dheerijijiji

# %%
a=True

# %%
 item1="silk"
 item2="Lays"
 item3="laptop"
 price_of_item1=150
 price_of_item2=550
 price_of_item3=3000000
 print("item1 :",item1,"price :",price_of_item1)
 print("item2 :",item2,"price :",price_of_item2)
 print("item3 :",item3,"price  :",price_of_item3)
 total_bill=price_of_item1+price_of_item2+price_of_item3
 print("total_bill   :", total_bill)
# Out:
# item1 : silk price : 150
# item2 : Lays price : 550
# item3 : laptop price  : 3000000
# total_bill   : 3000700

# %%
item1="lays"
item2="tuti fruti"
price_of_item1=304050
price_of_item2=7658
print("item1 :",item1,"price",price_of_item1)
print("item2 :",item2,"price",price_of_item2)
total_bill=price_of_item1+price_of_item2
print("total_bill  :",total_bill)
# Out:
# item1 : lays price 304050
# item2 : tuti fruti price 7658
# total_bill  : 311708

# %%
print("area of land :1000gaj")
print("cost of making house :155000000")
print("7Bhk house")
print("8 washrooms")
print("1 hall")
print("1 dining room")
print("2 kitchen one on first floor and second on third floor")
print("the house has to be of four floor")
print("on ground floor there has to be a garden,pool,and parking area ")
print("a roof")
# Out:
# area of land :1000gaj
# cost of making house :155000000
# 7Bhk house
# 8 washrooms
# 1 hall
# 1 dining room
# 2 kitchen one on first floor and second on third floor
# the house has to be of four floor
# on ground floor there has to be a garden,pool,and parking area
# a roof

# %%
item1="bottle"
item2="smart watch"
item3="laptop"
item4="dgi drone"
item5="hot glue gun"
price_of_item1=750
price_of_item2=1600
price_of_item3=150000
price_of_item4=250000
price_of_item5=350
print("item1 :",item1,"price",price_of_item1)
print("item2 :",item1,"price",price_of_item2)
print("item3 :",item3,"price",price_of_item3)
print("item4 :",item4,"price",price_of_item4)
print("item5 :",item5,"price",price_of_item5)
total_bill=price_of_item1+price_of_item2+price_of_item3+price_of_item4+price_of_item5
discount= total_bill *10/100
print("discount is : ", discount)
print("total_bill    :",total_bill)
payble_bill= total_bill - discount
print("price after discount :", payble_bill)
# Out:
# item1 : bottle price 750
# item2 : bottle price 1600
# item3 : laptop price 150000
# item4 : dgi drone price 250000
# item5 : hot glue gun price 350
# discount is :  40270.0
# total_bill    : 402700
# price after discount : 362430.0

# %%
item1=input("enter name of item1  :")
item2=input("enter name of item2  :")
item3=input("enter name of item3  :")
item4=input("enter name of item4  :")
price_of_item1=int(input("price of item1  :"))
price_of_item2=int(input("price of item2  :"))
price_of_item3=int(input("price of item3  :"))
price_of_item4=int(input("price of item4  :"))
print("item1 :",item1,"  price",price_of_item1)
print("item2 :",item2,"  price",price_of_item2)
print("item3 :",item3,"  price",price_of_item3)
print("item4 :",item4,"  price",price_of_item4)
total_bill=price_of_item1+price_of_item2+price_of_item3+price_of_item4
print("total_bill  :",total_bill)
discount=total_bill*15/100
print("discount  :",discount)
final_price_to_pay=total_bill-discount
print("final_price_to_pay  :",final_price_to_pay)
# Out:
# enter name of item1  :pizza
# enter name of item2  :manga
# enter name of item3  :pasta
# enter name of item4  :silk
# price of item1  :560
# price of item2  :330
# price of item3  :240
# price of item4  :230
# item1 : pizza   price 560
# item2 : manga   price 330
# item3 : pasta   price 240
# item4 : silk   price 230
# total_bill  : 1360
# discount  : 204.0
# final_price_to_pay  : 1156.0

# %%
item1= input(" name of item1  : ")
price_of_item1=int(input(" price of itm1  :"))
# Out:
#  name of item1  : pizza
#  price of itm1  :300

# %%
person1=input("name of person 1 :  ")
person2=input("name of person 2 :  ")
person3=input("name of person 3 :  ")
person4=input("name of person 4 :  ")
person5=input("name of person 5 :  ")
income_of_person_1=int(input("enter the income of person 1 :  "))
income_of_person_2=int(input("enter the income of person 2 :  "))
income_of_person_3=int(input("enter the income of person 3 :  "))
income_of_person_4=int(input("enter the income of person 4 :  "))
income_of_person_5=int(input("enter the income of person 5 :  "))
print("person 1  :",person1," income of person 1  :   ",income_of_person_1)
print("person 2  :",person2," income of person 2  :   ",income_of_person_2)
print("person 3  :",person3," income of person 3  :   ",income_of_person_3)
print("person 4  :",person4," income of person 4  :   ",income_of_person_4)
print("person 5  :",person5," income of person 5  :   ",income_of_person_5)
total_income=income_of_person_1+income_of_person_2+income_of_person_3+income_of_person_4+income_of_person_5
print("total_income   :",total_income)
spendicher=total_income*20/100
print("spendicher   :",spendicher)
saving=total_income-spendicher
print("savings   :",saving)
# Out:
# name of person 1 :  Virat Kohli
# name of person 2 :  Yuvraj Agarval
# name of person 3 :  Akshay Kumar
# name of person 4 :  Aarham Kothari
# name of person 5 :  Dheer Jain
# enter the income of person 1 :  90000
# enter the income of person 2 :  160000
# enter the income of person 3 :  120000
# enter the income of person 4 :  100000
# enter the income of person 5 :  200000
# person 1  : Virat Kohli  income of person 1  :    90000
# person 2  : Yuvraj Agarval  income of person 2  :    160000
# person 3  : Akshay Kumar  income of person 3  :    120000
# person 4  : Aarham Kothari  income of person 4  :    100000
# person 5  : Dheer Jain  income of person 5  :    200000
# total_income   : 670000
# spendicher   : 134000.0
# savings   : 536000.0

# %%
username=input("enter your username                          :  ")
birth_date=input("enter your birth date                      :  ")
gender=input("enter your gender                              :  ")
father_name=input("enter your father name                    :  ")
age=input("enter your age                                    :  ")
class_and_section=input("enter your class and section        :  ")
number=input("enter your number                              :  ")
friend_name=input("enter your friend name                    :  ")
favourite_food=input("enter your favourite food name         :  ")
passion=input("enter your pasion                             :  ")
favourite_sport=input("enter your favourite sport            :  ")
city=input("enter your city name                             :  ")
print()
print()
print("username  :  ",username)
print("birth date  :  ",birth_date)
print("gender  :  ",gender)
print("father name  :  ",father_name)
print("age  :  ",age)
print("class and section  :  ",class_and_section)
print("number  :  ",number)
print("friend name  :  ",friend_name)
print("favourite food  :  ",favourite_food)
print("passion  :  ",passion)
print("favourite sport  :  ",favourite_food)
print("city  :  ",city)
# Out:
# enter your username                          :  DHEER JAIN
# enter your birth date                      :  17/11/2012
# enter your gender                              :  MALE
# enter your father name                    :  AKSHAY JAIN
# enter your age                                    :  13
# enter your class and section        :  VII B
# enter your number                              :  9413752964
# enter your friend name                    :  YUVRAJ
# enter your favourite food name         :  CHINESE BHEL
# enter your pasion                             :  ARCHITECTURE
# enter your favourite sport            :  TENNIS
# enter your city name                             :  AJMER
#
#
# username  :   DHEER JAIN
# birth date  :   17/11/2012
# gender  :   MALE
# father name  :   AKSHAY JAIN
# age  :   13
# class and section  :   VII B
# number  :   9413752964
# friend name  :   YUVRAJ
# favourite food  :   CHINESE BHEL
# passion  :   ARCHITECTURE
# favourite sport  :   CHINESE BHEL
# ...

# %%
principal =int(input("enter principle amount : "))
rate=int(input("enter rate of interest"))
time=int(input("enter time"))
simple_interset= principal*rate*time/100
print("simple interest  :  ",simple_interset)
# Out:
# enter principle amount : 1000
# enter rate of interest7
# enter time9
# simple interest  :   630.0
